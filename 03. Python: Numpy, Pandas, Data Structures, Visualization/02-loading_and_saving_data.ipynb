# %% [markdown]
# # Loading CSV

# %%
import pandas as pd

# %%
# !ls data
# Out:
# '01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls'   results.csv    train.csv
#  AccidentesBicicletas_2019.csv		      results.xls
#  houses.csv				      results.xlsx

# %%
# !head data/AccidentesBicicletas_2019.csv
# Out:
# N�  EXPEDIENTE;FECHA;HORA;CALLE;N�MERO;DISTRITO;TIPO ACCIDENTE;ESTADO METEREOL�GICO;TIPO VEH�CULO;TIPO PERSONA;RANGO DE EDAD;SEXO;LESIVIDAD*
# 2019S000659;01/01/2019;14:00;CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ;-;SALAMANCA;Alcance;Despejado;Bicicleta;Conductor;DE 25 A 29 A�OS;Hombre;01
# 2019S000036;02/01/2019;20:45;AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES;-;HORTALEZA;Colisi�n fronto-lateral;Despejado;Bicicleta;Conductor;DE 70 A 74 A�OS;Hombre;03
# 2019S000133;03/01/2019;14:30;CALL. FELIPE ALVAREZ;10;VILLA DE VALLECAS;Alcance;Se desconoce;Bicicleta;Conductor;DE 15 A 17 A�OS;Hombre;07
# 2019S000132;03/01/2019;12:45;AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA;-;VILLA DE VALLECAS;Alcance;Despejado;Bicicleta;Conductor;DE 18 A 20 A�OS;Hombre;07
# 2019S000132;03/01/2019;12:45;AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA;-;VILLA DE VALLECAS;Alcance;Despejado;Bicicleta;Conductor;DE 21 A 24 A�OS;Hombre;14
# ...

# %%
pd.read_csv('./data/AccidentesBicicletas_2019.csv', encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-00d5d3e50fe7> in <module>
# ----> 1 pd.read_csv('./data/AccidentesBicicletas_2019.csv', encoding='latin1')
#
# ~/anaconda3/envs/kschool_mds_19/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
df =pd.read_csv('./data/AccidentesBicicletas_2019.csv', encoding='latin1',sep=';')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.Series(df.columns).str.lower().str.replace('','').str.split().apply(lambda x: x[-1])
# Out:
# 0        expediente
# 1             fecha
# 2              hora
# 3             calle
# 4            número
# 5          distrito
# 6         accidente
# 7     metereológico
# 8          vehículo
# 9           persona
# 10             edad
# 11             sexo
# 12       lesividad*
# dtype: object

# %% [markdown]
# # Saving to Excel

# %%
df.to_excel('data/results.xls')

# %%
df.to_excel('data/results.xlsx')

# %% [markdown]
# # Saving to CSV

# %%
df.to_csv('data/results.csv', sep=";")

# %%
df.to_csv('data/results.csv', sep="^")

# %% [markdown]
# # Reading Excel

# %%
pd.read_excel('data/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls', sheet_name='2010', skiprows=7, index_col=0,
             usecols="A:K", skipfooter=1)
# Out:
#                                 COLISIÓN DOBLE                            \
# DISTRITO_ACCIDENTE
# ARGANZUELA                                                           403
# BARAJAS                                                               62
# CARABANCHEL                                                          357
# CENTRO                                                               546
# CHAMARTIN                                                            460
# CHAMBERI                                                             361
# CIUDAD LINEAL                                                        404
# FUENCARRAL-EL PARDO                                                  294
# HORTALEZA                                                            183
# LATINA                                                               273
# MONCLOA-ARAVACA                                                      350
# MORATALAZ                                                            127
# ...

# %% [markdown]
# #### Homework
#
# Consolidate the excel into one DataFrame: you will need to create a 'YEAR' column. Think how you can iterate through all the DataFrames. Think also where you can take the value of 'YEAR' from.

# %% [markdown]
# # To Sql Database

# %%
import sqlite3

connection = sqlite3.connect('newdb.db')

# %%
df.to_sql('mynewtable', con=connection, if_exists='replace')
# Out:
# /home/bsanse/anaconda3/envs/kschool_mds_19/lib/python3.7/site-packages/pandas/core/generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %% [markdown]
# # To dictionary and to json

# %%
df.head().to_dict()
# Out:
# {'Nº  EXPEDIENTE': {0: '2019S000659',
#   1: '2019S000036',
#   2: '2019S000133',
#   3: '2019S000132',
#   4: '2019S000132'},
#  'FECHA': {0: '01/01/2019',
#   1: '02/01/2019',
#   2: '03/01/2019',
#   3: '03/01/2019',
#   4: '03/01/2019'},
#  'HORA': {0: '14:00', 1: '20:45', 2: '14:30', 3: '12:45', 4: '12:45'},
#  'CALLE': {0: 'CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ',
#   1: 'AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES',
#   2: 'CALL. FELIPE ALVAREZ',
#   3: 'AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA',
#   4: 'AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA'},
#  'NÚMERO': {0: '-', 1: '-', 2: '10', 3: '-', 4: '-'},
#  'DISTRITO': {0: 'SALAMANCA',
#   1: 'HORTALEZA',
#   2: 'VILLA DE VALLECAS',
#   3: 'VILLA DE VALLECAS',
#   4: 'VILLA DE VALLECAS'},
#  'TIPO ACCIDENTE': {0: 'Alcance',
#   1: 'Colisión fronto-lateral',
#   2: 'Alcance',
#   3: 'Alcance',
#   4: 'Alcance'},
#  'ESTADO METEREOLÓGICO': {0: 'Despejado',
#   1: 'Despejado',
#   2: 'Se desconoce',
# ...

# %%
df.head().to_json()
# Out:
# '{"N\\u00ba  EXPEDIENTE":{"0":"2019S000659","1":"2019S000036","2":"2019S000133","3":"2019S000132","4":"2019S000132"},"FECHA":{"0":"01\\/01\\/2019","1":"02\\/01\\/2019","2":"03\\/01\\/2019","3":"03\\/01\\/2019","4":"03\\/01\\/2019"},"HORA":{"0":"14:00","1":"20:45","2":"14:30","3":"12:45","4":"12:45"},"CALLE":{"0":"CALL. CASTELLO \\/ CALL. DON RAMON DE LA CRUZ","1":"AVDA. GRAN VIA DE HORTALEZA \\/ GTA. LUIS ROSALES","2":"CALL. FELIPE ALVAREZ","3":"AVDA. SANTA EUGENIA \\/ CALL. REAL DE ARGANDA","4":"AVDA. SANTA EUGENIA \\/ CALL. REAL DE ARGANDA"},"N\\u00daMERO":{"0":"-","1":"-","2":"10","3":"-","4":"-"},"DISTRITO":{"0":"SALAMANCA","1":"HORTALEZA","2":"VILLA DE VALLECAS","3":"VILLA DE VALLECAS","4":"VILLA DE VALLECAS"},"TIPO ACCIDENTE":{"0":"Alcance","1":"Colisi\\u00f3n fronto-lateral","2":"Alcance","3":"Alcance","4":"Alcance"},"ESTADO METEREOL\\u00d3GICO":{"0":"Despejado","1":"Despejado","2":"Se desconoce","3":"Despejado","4":"Despejado"},"TIPO VEH\\u00cdCULO":{"0":"Bicicleta","1":"Bici
# ...

# %% [markdown]
# # Reading mysql database

# %%
pd.read_sql_query("SELECT FECHA, HORA FROM mynewtable WHERE SEXO = 'Hombre' LIMIT 10", connection)
# Out:
#         FECHA   HORA
# 0  01/01/2019  14:00
# 1  02/01/2019  20:45
# 2  03/01/2019  14:30
# 3  03/01/2019  12:45
# 4  03/01/2019  12:45
# 5  03/01/2019  10:30
# 6  04/01/2019  17:10
# 7  04/01/2019  13:35
# 8  07/01/2019  14:00
# 9  08/01/2019  20:55
